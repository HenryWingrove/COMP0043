# %%
epsm = 1
for i in range(100):
    epsm = epsm/2
    if 1+epsm == 1:
        break
epsm = 2* epsm
print(epsm)

epsm = 1/(2**i)
print(epsm)

epsm = 1.0
while 1.0+epsm != 1.0:
    epsm = epsm/2

epsm = 2*epsm
print(epsm)
# Out:
# 2.220446049250313e-16
# 2.220446049250313e-16
# 2.220446049250313e-16
